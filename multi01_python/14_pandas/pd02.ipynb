# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# %%
random_num = np.random.randint(1, 101, [3, 3])
random_num
# 행렬
# Out:
# array([[19, 70,  8],
#        [25, 11, 58],
#        [94, 57, 15]], dtype=int32)

# %%
df_num = pd.DataFrame(random_num)
df_num
# 데이터프레임으로 변환해줌
# Out:
#     0   1   2
# 0  19  70   8
# 1  25  11  58
# 2  94  57  15

# %%
df_num = pd.DataFrame(random_num, index=["row1", "row2", "row3"])
df_num
# Out:
#        0   1   2
# row1  19  70   8
# row2  25  11  58
# row3  94  57  15

# %%
df_num = pd.DataFrame(random_num,
                      index=["row1", "row2", "row3"],
                      columns=["col1", "col2", "col3"])
df_num
# Out:
#       col1  col2  col3
# row1    19    70     8
# row2    25    11    58
# row3    94    57    15

# %%
print(type(random_num))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(df_num))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 출력 형식 차이
# 파이참 미적 감각 무시 ㅋ
print(random_num)
# Out:
# [[19 70  8]
#  [25 11 58]
#  [94 57 15]]

# %%
print(df_num)
# Out:
#       col1  col2  col3
# row1    19    70     8
# row2    25    11    58
# row3    94    57    15

# %%
books = {
    "title" : ["개미", "고구려", "드래곤라자", "퇴마록"],
    "writer": ["베르나르 베르베르", "김진명", "이영도", "이우혁"],
    "publisher": ["열린책들", "이타북스", "황금가지", "들녘"],
    "1st-edition": ["2013-05-30", "2011-02-28", "1998-05-30", "1994-01-01"],
    "price" : [15000, 15000, 6300, 8550]
}

# %%
books
# Out:
# {'title': ['개미', '고구려', '드래곤라자', '퇴마록'],
#  'writer': ['베르나르 베르베르', '김진명', '이영도', '이우혁'],
#  'publisher': ['열린책들', '이타북스', '황금가지', '들녘'],
#  '1st-edition': ['2013-05-30', '2011-02-28', '1998-05-30', '1994-01-01'],
#  'price': [15000, 15000, 6300, 8550]}

# %%
df_books = pd.DataFrame(books)
df_books
# Out:
#    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300
# 3    퇴마록        이우혁        들녘  1994-01-01   8550

# %%
print(df_books)
# Out:
#    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300
# 3    퇴마록        이우혁        들녘  1994-01-01   8550

# %%
df_books.index
df_books.columns
df_books.shape
df_books.size
print(df_books.dtypes)
type(df_books.dtypes)
print(df_books.count())
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['title', 'writer', 'publisher', '1st-edition', 'price'], dtype='object')
# (4, 5)
# 20
# title          object
# writer         object
# publisher      object
# 1st-edition    object
# price           int64
# dtype: object
# pandas.core.series.Series
# title          4
# writer         4
# publisher      4
# 1st-edition    4
# price          4
# dtype: int64

# %%
df_books.info
df_books.info()
# Out:
# <bound method DataFrame.info of    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300
# 3    퇴마록        이우혁        들녘  1994-01-01   8550>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4 non-null      object
#  1   writer       4 non-null      object
#  2   publisher    4 non-null      object
#  3   1st-edition  4 non-null      object
#  4   price        4 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 292.0+ bytes

# %%
df_books["title"][0]
# Out:
# '개미'

# %%
type(df_books["title"])
# Out:
# pandas.core.series.Series

# %%
df_books["price"].max()
# Out:
# np.int64(15000)

# %%
df_books["price"].min()
# Out:
# np.int64(6300)

# %%
df_books.sort_values(by="price")
# Out:
#    title     writer publisher 1st-edition  price
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300
# 3    퇴마록        이우혁        들녘  1994-01-01   8550
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000

# %%
df_books.sort_values(by="price", ascending=False)
# 내림차순 설정
# Out:
#    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 3    퇴마록        이우혁        들녘  1994-01-01   8550
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300

# %%
df_books.sort_values(["price", "1st-edition"], ascending=False)
# Out:
#    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 3    퇴마록        이우혁        들녘  1994-01-01   8550
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300

# %%
df_books.sort_values(["price", "1st-edition"], ascending=[False, True])
# Out:
#    title     writer publisher 1st-edition  price
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 3    퇴마록        이우혁        들녘  1994-01-01   8550
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300

# %%
df_books.sort_index()
# Out:
#    title     writer publisher 1st-edition  price
# 0     개미  베르나르 베르베르      열린책들  2013-05-30  15000
# 1    고구려        김진명      이타북스  2011-02-28  15000
# 2  드래곤라자        이영도      황금가지  1998-05-30   6300
# 3    퇴마록        이우혁        들녘  1994-01-01   8550

# %%
df_books.sort_index(axis=1)
# Out:
#   1st-edition  price publisher  title     writer
# 0  2013-05-30  15000      열린책들     개미  베르나르 베르베르
# 1  2011-02-28  15000      이타북스    고구려        김진명
# 2  1998-05-30   6300      황금가지  드래곤라자        이영도
# 3  1994-01-01   8550        들녘    퇴마록        이우혁

# %%
df_books.sort_index(axis="columns")
# Out:
#   1st-edition  price publisher  title     writer
# 0  2013-05-30  15000      열린책들     개미  베르나르 베르베르
# 1  2011-02-28  15000      이타북스    고구려        김진명
# 2  1998-05-30   6300      황금가지  드래곤라자        이영도
# 3  1994-01-01   8550        들녘    퇴마록        이우혁

# %%
df_title = df_books.set_index("title")

# %%
df_title
# Out:
#           writer publisher 1st-edition  price
# title
# 개미     베르나르 베르베르      열린책들  2013-05-30  15000
# 고구려          김진명      이타북스  2011-02-28  15000
# 드래곤라자        이영도      황금가지  1998-05-30   6300
# 퇴마록          이우혁        들녘  1994-01-01   8550

# %%
df_title.index
# Out:
# Index(['개미', '고구려', '드래곤라자', '퇴마록'], dtype='object', name='title')

# %%
df_title.values
# Out:
# array([['베르나르 베르베르', '열린책들', '2013-05-30', 15000],
#        ['김진명', '이타북스', '2011-02-28', 15000],
#        ['이영도', '황금가지', '1998-05-30', 6300],
#        ['이우혁', '들녘', '1994-01-01', 8550]], dtype=object)

# %%
df_title["price"]
# Out:
# title
# 개미       15000
# 고구려      15000
# 드래곤라자     6300
# 퇴마록       8550
# Name: price, dtype: int64

# %%
type(df_title["price"])
# 인덱스가 title이 된 시리즈 타입 맞는지 확인
# Out:
# pandas.core.series.Series

# %%
df_title.nlargest(3, columns="price")
# Out:
#           writer publisher 1st-edition  price
# title
# 개미     베르나르 베르베르      열린책들  2013-05-30  15000
# 고구려          김진명      이타북스  2011-02-28  15000
# 퇴마록          이우혁        들녘  1994-01-01   8550

# %%
df_title.nsmallest(2, columns="price")
# Out:
#       writer publisher 1st-edition  price
# title
# 드래곤라자    이영도      황금가지  1998-05-30   6300
# 퇴마록      이우혁        들녘  1994-01-01   8550

# %%
df_title.sum()
# Out:
# writer                               베르나르 베르베르김진명이영도이우혁
# publisher                                열린책들이타북스황금가지들녘
# 1st-edition    2013-05-302011-02-281998-05-301994-01-01
# price                                             44850
# dtype: object

# %%
df_title
# Out:
#           writer publisher 1st-edition  price
# title
# 개미     베르나르 베르베르      열린책들  2013-05-30  15000
# 고구려          김진명      이타북스  2011-02-28  15000
# 드래곤라자        이영도      황금가지  1998-05-30   6300
# 퇴마록          이우혁        들녘  1994-01-01   8550

# %%
# 컬럼별로 값을 더함. == 시리즈별로 값을 더함
df_title.sum()
# Out:
# writer                               베르나르 베르베르김진명이영도이우혁
# publisher                                열린책들이타북스황금가지들녘
# 1st-edition    2013-05-302011-02-281998-05-301994-01-01
# price                                             44850
# dtype: object

# %%
df_title["price"].sum()
# Out:
# np.int64(44850)

# %%
df_title.sum(numeric_only=True)
# Out:
# price    44850
# dtype: int64

# %%
df_title.sum(numeric_only=False) # 기본값 false
# Out:
# writer                               베르나르 베르베르김진명이영도이우혁
# publisher                                열린책들이타북스황금가지들녘
# 1st-edition    2013-05-302011-02-281998-05-301994-01-01
# price                                             44850
# dtype: object

# %%
df_title.mean(numeric_only=True)
# Out:
# price    11212.5
# dtype: float64

# %%
df_title.median(numeric_only=True)
# Out:
# price    11775.0
# dtype: float64

# %%
df_title.std(numeric_only=True)
# Out:
# price    4468.850523
# dtype: float64

# %%
df_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 개미 to 퇴마록
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   writer       4 non-null      object
#  1   publisher    4 non-null      object
#  2   1st-edition  4 non-null      object
#  3   price        4 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
df_title.info
# Out:
# <bound method DataFrame.info of           writer publisher 1st-edition  price
# title
# 개미     베르나르 베르베르      열린책들  2013-05-30  15000
# 고구려          김진명      이타북스  2011-02-28  15000
# 드래곤라자        이영도      황금가지  1998-05-30   6300
# 퇴마록          이우혁        들녘  1994-01-01   8550>

# %%
df_title.select_dtypes("object")
# object 타입으로 되어있는애들만 보여줘
# Out:
#           writer publisher 1st-edition
# title
# 개미     베르나르 베르베르      열린책들  2013-05-30
# 고구려          김진명      이타북스  2011-02-28
# 드래곤라자        이영도      황금가지  1998-05-30
# 퇴마록          이우혁        들녘  1994-01-01

# %%
df_title.select_dtypes("int")
# Out:
#        price
# title
# 개미     15000
# 고구려    15000
# 드래곤라자   6300
# 퇴마록     8550

# %%
df_title["1st-edition"] = pd.to_datetime(df_title["1st-edition"])

# %%
df_title.select_dtypes("object")
# Out:
#           writer publisher
# title
# 개미     베르나르 베르베르      열린책들
# 고구려          김진명      이타북스
# 드래곤라자        이영도      황금가지
# 퇴마록          이우혁        들녘

# %%
df_title.select_dtypes(include="object")
# Out:
#           writer publisher
# title
# 개미     베르나르 베르베르      열린책들
# 고구려          김진명      이타북스
# 드래곤라자        이영도      황금가지
# 퇴마록          이우혁        들녘

# %%
df_title.select_dtypes(exclude="object")
# Out:
#       1st-edition  price
# title
# 개미     2013-05-30  15000
# 고구려    2011-02-28  15000
# 드래곤라자  1998-05-30   6300
# 퇴마록    1994-01-01   8550

# %%
df_title["price"]
# Out:
# title
# 개미       15000
# 고구려      15000
# 드래곤라자     6300
# 퇴마록       8550
# Name: price, dtype: int64

# %%
df_title["publisher"]
# Out:
# title
# 개미       열린책들
# 고구려      이타북스
# 드래곤라자    황금가지
# 퇴마록        들녘
# Name: publisher, dtype: object

# %%
# 두개를 조회해서 보고싶을때
df_title[["price", "publisher"]]
# Out:
#        price publisher
# title
# 개미     15000      열린책들
# 고구려    15000      이타북스
# 드래곤라자   6300      황금가지
# 퇴마록     8550        들녘

# %%
# 잘못된 사례
df_title["price", "publisher"]
# KeyError: ('price', 'publisher')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\multi01\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('price', 'publisher')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 # 잘못된 사례
# ----> 2 df_title["price", "publisher"]
#       3 # KeyError: ('price', 'publisher')
#
# File ~\anaconda3\envs\multi01\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\anaconda3\envs\multi01\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: ('price', 'publisher')

# %%
# 알맞은 사례. 대괄호 하나 더 작성해줌
df_title[["price", "publisher"]]
# Out:
#        price publisher
# title
# 개미     15000      열린책들
# 고구려    15000      이타북스
# 드래곤라자   6300      황금가지
# 퇴마록     8550        들녘

# %%
print(df_title.loc["드래곤라자"])
# Out:
# writer                         이영도
# publisher                     황금가지
# 1st-edition    1998-05-30 00:00:00
# price                         6300
# Name: 드래곤라자, dtype: object

# %%
print(df_title.iloc[2])
# Out:
# writer                         이영도
# publisher                     황금가지
# 1st-edition    1998-05-30 00:00:00
# price                         6300
# Name: 드래곤라자, dtype: object

# %%
df_title.loc[["고구려", "드래곤라자"]]
# Out:
#       writer publisher 1st-edition  price
# title
# 고구려      김진명      이타북스  2011-02-28  15000
# 드래곤라자    이영도      황금가지  1998-05-30   6300

# %%
df_title.iloc[[1, 2]]
# Out:
#       writer publisher 1st-edition  price
# title
# 고구려      김진명      이타북스  2011-02-28  15000
# 드래곤라자    이영도      황금가지  1998-05-30   6300

# %%
df_title.iloc[2:4]
# Out:
#       writer publisher 1st-edition  price
# title
# 드래곤라자    이영도      황금가지  1998-05-30   6300
# 퇴마록      이우혁        들녘  1994-01-01   8550
