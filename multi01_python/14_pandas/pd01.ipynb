# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\envs\multi01\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\multi01\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\multi01\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------------------------- ------------- 7.3/11.0 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 36.8 MB/s  0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.2 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
numbers = [19, 2, 8, 22, 42, 32, 39]

# %%
lotto = pd.Series(data = numbers)
lotto
# Out:
# 0    19
# 1     2
# 2     8
# 3    22
# 4    42
# 5    32
# 6    39
# dtype: int64

# %%
index = ['1', '2', '3', '4', '5', '6', 'bonus']
lotto = pd.Series(data=numbers, index=index)

# %%
lotto
# Out:
# 1        19
# 2         2
# 3         8
# 4        22
# 5        42
# 6        32
# bonus    39
# dtype: int64

# %%
print(lotto.index)
# Out:
# Index(['1', '2', '3', '4', '5', '6', 'bonus'], dtype='object')

# %%
print(type(lotto.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print(lotto.values)
# Out:
# [19  2  8 22 42 32 39]

# %%
print(type(lotto.values))
# Out:
# <class 'numpy.ndarray'>

# %%
random_num = np.random.randint(1, 45, 6)
# 1부터 45까지 6개 랜덤숫자

# %%
random_num
# Out:
# array([40, 13, 23, 31, 26, 28], dtype=int32)

# %%
today_lotto = pd.Series(random_num, dtype="float")

# %%
today_lotto
# Out:
# 0    40.0
# 1    13.0
# 2    23.0
# 3    31.0
# 4    26.0
# 5    28.0
# dtype: float64

# %%
today_lotto.is_unique
# 랜덤값에 중복값이 있는지 없는지 확인
# Out:
# True

# %%
today_lotto.is_monotonic_increasing
# 값이 연속해서 증가하는지 확인
# Out:
# False

# %%
pd.Series([1, 4, 6, 7, 9, 100]).is_monotonic_increasing
# Out:
# True

# %%
pd.Series([1, 4, 6, 7, 9, 100]).is_monotonic_decreasing
# Out:
# False

# %%
pd.Series([10, 7, 6, 5, 1]).is_monotonic_decreasing
# 값이 연속해서 감소하는지 확인
# Out:
# True

# %%
nums = pd.Series(range(100, 1001, 100))

# %%
nums
# Out:
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500
# 5     600
# 6     700
# 7     800
# 8     900
# 9    1000
# dtype: int64

# %%
print(nums)
print(type(nums))
# Out:
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500
# 5     600
# 6     700
# 7     800
# 8     900
# 9    1000
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
nums.head()
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
nums.head(8)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# 5    600
# 6    700
# 7    800
# dtype: int64

# %%
nums.head(3)
# nums.head(n=3)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
nums.head(n=3)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
nums.tail()
# Out:
# 5     600
# 6     700
# 7     800
# 8     900
# 9    1000
# dtype: int64

# %%
nums.tail(3)
# Out:
# 7     800
# 8     900
# 9    1000
# dtype: int64

# %%
nums.sum()
# Out:
# np.int64(5500)

# %%
nums
# Out:
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500
# 5     600
# 6     700
# 7     800
# 8     900
# 9    1000
# dtype: int64

# %%
# nan = Not A Number
nums[1] = np.nan
nums
# Out:
# 0     100.0
# 1       NaN
# 2     300.0
# 3     400.0
# 4     500.0
# 5     600.0
# 6     700.0
# 7     800.0
# 8     900.0
# 9    1000.0
# dtype: float64

# %%
nums.sum()
# Out:
# np.float64(5300.0)

# %%
nums.sum(skipna=False)
# 중간에 숫자 아닌 값 들어가 있어서 계산 불가하다 함
# Out:
# np.float64(nan)

# %%
# 누적합
print(nums.cumsum())
# Out:
# 0     100.0
# 1       NaN
# 2     400.0
# 3     800.0
# 4    1300.0
# 5    1900.0
# 6    2600.0
# 7    3400.0
# 8    4300.0
# 9    5300.0
# dtype: float64

# %%
# 평균
print(nums.mean())
# Out:
# 588.8888888888889

# %%
# 중위값
print(nums.median())
# Out:
# 600.0

# %%
# 표준편차
print(nums.std())
# Out:
# 293.4469476943168

# %%
# max, min
print(nums.max())
print(nums.min())
# Out:
# 1000.0
# 100.0

# %%
# describe
print(nums.describe())
# Out:
# count       9.000000
# mean      588.888889
# std       293.446948
# min       100.000000
# 25%       400.000000
# 50%       600.000000
# 75%       800.000000
# max      1000.000000
# dtype: float64

# %%
# nums 값 확인
nums
# Out:
# 0     100.0
# 1       NaN
# 2     300.0
# 3     400.0
# 4     500.0
# 5     600.0
# 6     700.0
# 7     800.0
# 8     900.0
# 9    1000.0
# dtype: float64

# %%
num_list = [
    [19, 2, 8, 22, 42, 32, 39],
    [6, 10, 12, 14, 20, 42, 15]
]
lotto_list = pd.Series(num_list, index=["1000회", "1001회"])
lotto_list
# Out:
# 1000회     [19, 2, 8, 22, 42, 32, 39]
# 1001회    [6, 10, 12, 14, 20, 42, 15]
# dtype: object

# %%
num_dict = {"1000회": [19, 2, 8, 22, 42, 32, 39],
            "1001회": [6, 10, 12, 14, 20, 42, 15]}
lotto_dict = pd.Series(num_dict)

# %%
num_dict
# Out:
# {'1000회': [19, 2, 8, 22, 42, 32, 39], '1001회': [6, 10, 12, 14, 20, 42, 15]}

# %%
heroes = ["CaptainAmerica", "Thor", "Hulk", "IronMan", "BlackWidow", "HawkEye", "Hulk"]
avengers = pd.Series(heroes)
avengers
# Out:
# 0    CaptainAmerica
# 1              Thor
# 2              Hulk
# 3           IronMan
# 4        BlackWidow
# 5           HawkEye
# 6              Hulk
# dtype: object

# %%
avengers.is_unique
# Out:
# False

# %%
avengers.unique()
# Out:
# array(['CaptainAmerica', 'Thor', 'Hulk', 'IronMan', 'BlackWidow',
#        'HawkEye'], dtype=object)

# %%
avengers.nunique()
# Out:
# 6

# %%
# 문자 첫글자의 유니코드를 통해 순서를 조회함
avengers.max()
# Out:
# 'Thor'

# %%
avengers.min()
# Out:
# 'BlackWidow'

# %%
avengers.sort_values()
# Out:
# 4        BlackWidow
# 0    CaptainAmerica
# 5           HawkEye
# 2              Hulk
# 6              Hulk
# 3           IronMan
# 1              Thor
# dtype: object

# %%
list(avengers)
# Out:
# ['CaptainAmerica', 'Thor', 'Hulk', 'IronMan', 'BlackWidow', 'HawkEye', 'Hulk']

# %%
dict(avengers)
# Out:
# {0: 'CaptainAmerica',
#  1: 'Thor',
#  2: 'Hulk',
#  3: 'IronMan',
#  4: 'BlackWidow',
#  5: 'HawkEye',
#  6: 'Hulk'}

# %%
'CaptainAmerica' in avengers
# Out:
# False

# %%
'CaptainAmerica' in avengers.values
# Out:
# True

# %%
0 in avengers
# Out:
# True

# %%
series01 = pd.Series([1, 2, 3, 4, 5])
series02 = pd.Series([1, 3, 5, 7, 9])

# %%
series01
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series02
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
series01 + 5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
series01.add(5)
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
series02 - 5
# Out:
# 0   -4
# 1   -2
# 2    0
# 3    2
# 4    4
# dtype: int64

# %%
series02.sub(5)
# Out:
# 0   -4
# 1   -2
# 2    0
# 3    2
# 4    4
# dtype: int64

# %%
series02.subtract(5)
# Out:
# 0   -4
# 1   -2
# 2    0
# 3    2
# 4    4
# dtype: int64

# %%
series01 == series02
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
series01
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series02
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
series01 == series02
# 각각의 인덱스에 맞는 값들끼리 비교해서 논리연산자를 출력하는것 확인할 수 있음
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
print(series01 != series02)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
print(series01.ne(series02))
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
print(series01.eq(series02))
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
series03 = pd.Series([1, 2, 3, 4, 5], index=["a", "b", "c", "d", "e"])
series04 = pd.Series([6, 7, 8, 9, 10], index=["c", "d", "e", "f", "g"])

# %%
series03 + series04
# Out:
# a     NaN
# b     NaN
# c     9.0
# d    11.0
# e    13.0
# f     NaN
# g     NaN
# dtype: float64

# %%
series03 = pd.Series([1, 2, 3, 4, 5], index=["a", "b", "c", "d", "e"])
series04 = pd.Series([9, 10], index=["f", "g"])
series03 + series04
# 인덱스 기준으로 더하는걸 확인할 수 있음
# Out:
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# f   NaN
# g   NaN
# dtype: float64
