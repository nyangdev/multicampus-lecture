# %%
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = load_data()

# %%
x_train_scale = x_train / 255.0
x_test_scale = x_test / 255.0

# %%
model = Sequential([
    Flatten(),
    Dense(64, activation="relu"),
    Dense(32, activation="relu"),
    Dropout(0.5),
    Dense(16, activation="relu"),
    Dense(8, activation="relu"),
    Dense(10, activation="softmax"),
])

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["acc"])

# %%
result = model.fit(x_train_scale, y_train, epochs=100, batch_size=100, callbacks=[EarlyStopping(monitor="val_loss")],
                   validation_split=0.2)
# Out:
# Epoch 1/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - acc: 0.4391 - loss: 1.5808 - val_acc: 0.9110 - val_loss: 0.3707
# Epoch 2/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.8268 - loss: 0.5866 - val_acc: 0.9358 - val_loss: 0.2412
# Epoch 3/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.8795 - loss: 0.4162 - val_acc: 0.9463 - val_loss: 0.2054
# Epoch 4/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.8994 - loss: 0.3451 - val_acc: 0.9523 - val_loss: 0.1898
# Epoch 5/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9097 - loss: 0.2991 - val_acc: 0.9553 - val_loss: 0.1714
# Epoch 6/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9202 - loss: 0.2730 - val_acc: 0.9576 - val_loss: 0.1651
# Epoch 7/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9283 - loss: 0.2470 - val_acc: 0.9595 - val_loss: 0.1594
# Epoch 8/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9332 - loss: 0.2277 - val_acc: 0.9608 - val_loss: 0.1573
# Epoch 9/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.9366 - loss: 0.2217 - val_acc: 0.9625 - val_loss: 0.1508
# Epoch 10/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9390 - loss: 0.2027 - val_acc: 0.9617 - val_loss: 0.1491
# Epoch 11/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9428 - loss: 0.1911 - val_acc: 0.9622 - val_loss: 0.1473
# Epoch 12/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - acc: 0.9450 - loss: 0.1807 - val_acc: 0.9644 - val_loss: 0.1418
# Epoch 13/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9474 - loss: 0.1687 - val_acc: 0.9659 - val_loss: 0.1432

# %%
model.evaluate(x_test_scale, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9572 - loss: 0.1666
# [0.14671730995178223, 0.9641000032424927]

# %%
model.save("dl12.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("dl12.keras")
