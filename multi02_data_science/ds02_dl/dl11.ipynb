# %%
import os

from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = load_data()

# %%
x_train_scale = x_train / 255.0
x_test_scale = x_test / 255.0

# %%
model = Sequential([
    Flatten(),
    Dense(8, activation="relu"),
    Dense(32, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "adam",
              metrics = ["acc"])

# %%
load_dir = "dl10_checkpoins"

if os.path.exists(load_dir):
    ckpt_list = os.listdir(load_dir)

print(ckpt_list)
# Out:
# ['2025_10_27_14_17_10_0.2264.keras', '2025_10_27_14_17_11_0.2218.keras', '2025_10_27_14_17_12_0.2216.keras', '2025_10_27_14_17_13_0.2176.keras', '2025_10_27_14_17_14_0.2134.keras', '2025_10_27_14_17_17_0.2088.keras', '2025_10_27_14_17_1_0.3642.keras', '2025_10_27_14_17_21_0.2035.keras', '2025_10_27_14_17_22_0.2028.keras', '2025_10_27_14_17_25_0.2012.keras', '2025_10_27_14_17_29_0.1993.keras', '2025_10_27_14_17_2_0.3038.keras', '2025_10_27_14_17_32_0.1970.keras', '2025_10_27_14_17_39_0.1949.keras', '2025_10_27_14_17_3_0.2722.keras', '2025_10_27_14_17_4_0.2561.keras', '2025_10_27_14_17_5_0.2530.keras', '2025_10_27_14_17_6_0.2456.keras', '2025_10_27_14_17_7_0.2381.keras', '2025_10_27_14_17_8_0.2324.keras', '2025_10_27_14_17_9_0.2300.keras']

# %%
model.build(input_shape=x_train_scale.shape)

# %%
path = load_dir + "/" + ckpt_list[len(ckpt_list) // 2]
path
# Out:
# 'dl10_checkpoins/2025_10_27_14_17_29_0.1993.keras'

# %%
model.load_weights(path)
# Out:
# c:\Users\user\anaconda3\envs\multi02_tensor\lib\site-packages\keras\src\saving\saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
result = model.fit(x_train_scale, y_train, batch_size=100,
                   epochs=100,
                   callbacks=[EarlyStopping(monitor="val_loss", patience=3)],
                   validation_split=0.2)
# Out:
# Epoch 1/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - acc: 0.9534 - loss: 0.1564 - val_acc: 0.9406 - val_loss: 0.2049
# Epoch 2/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9533 - loss: 0.1591 - val_acc: 0.9414 - val_loss: 0.2102
# Epoch 3/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9536 - loss: 0.1543 - val_acc: 0.9446 - val_loss: 0.1956
# Epoch 4/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9555 - loss: 0.1540 - val_acc: 0.9448 - val_loss: 0.1969
# Epoch 5/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - acc: 0.9544 - loss: 0.1574 - val_acc: 0.9427 - val_loss: 0.1991
# Epoch 6/100
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9541 - loss: 0.1553 - val_acc: 0.9427 - val_loss: 0.2035

# %%
model.evaluate(x_test_scale, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.9348 - loss: 0.2219
# [0.20174284279346466, 0.9423999786376953]
