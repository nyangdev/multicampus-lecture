# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %% [markdown]
# naive bayes, knn(k=3), decision tree(depth=3)로 펭귄의 종을 예측하는 모델을 만들고 학습시키자
#
# 각 모델의 정확도, f1 score, precision score, recall score, roc auc score 를 출력하자

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
x = penguins[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]]
y = penguins["species"]

# %%
x
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
y
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
x.isna().sum()
# Out:
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# dtype: int64

# %%
y.isna().sum()
# Out:
# np.int64(0)

# %%
x = x.dropna()
y = y.loc[x.index]

# %%
x
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [342 rows x 4 columns]

# %%
y
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 4      Adelie
# 5      Adelie
#         ...
# 338    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 342, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
naive_model = GaussianNB()

# %%
naive_model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_model = DecisionTreeClassifier(max_depth=3)
decision_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# 각 모델의 정확도, f1 score, precision score, recall score, roc auc score 를 출력하자

# %%
# naive_model, knn_model, decision_model

# %%
naive_model.score(x_test, y_test)
# Out:
# 0.9611650485436893

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.8252427184466019

# %%
decision_model.score(x_test, y_test)
# Out:
# 0.9611650485436893

# %%
naive_predict = naive_model.predict(x_test)

# %%
accuracy_score(y_test, naive_predict)
# Out:
# 0.9611650485436893

# %%
knn_predict = knn_model.predict(x_test)

# %%
accuracy_score(y_test, knn_predict)
# Out:
# 0.8252427184466019

# %%
decision_predict = decision_model.predict(x_test)

# %%
accuracy_score(y_test, decision_predict)
# Out:
# 0.9611650485436893

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, naive_predict, average=None)
# Out:
# array([0.95652174, 0.88235294, 1.        ])

# %%
f1_score(y_test, knn_predict, average=None)
# Out:
# array([0.8172043 , 0.53333333, 0.93975904])

# %%
f1_score(y_test, decision_predict, average=None)
# Out:
# array([0.95652174, 0.91428571, 0.98734177])

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test, naive_predict, average=None)
# Out:
# array([0.93617021, 0.9375    , 1.        ])

# %%
precision_score(y_test, knn_predict, average=None)
# Out:
# array([0.79166667, 0.66666667, 0.90697674])

# %%
precision_score(y_test, decision_predict, average=None)
# Out:
# array([0.93617021, 0.94117647, 1.        ])

# %%
from sklearn.metrics import recall_score

# %%
recall_score(y_test, naive_predict, average=None)
# Out:
# array([0.97777778, 0.83333333, 1.        ])

# %%
recall_score(y_test, knn_predict, average=None)
# Out:
# array([0.84444444, 0.44444444, 0.975     ])

# %%
recall_score(y_test, decision_predict, average=None)
# Out:
# array([0.97777778, 0.88888889, 0.975     ])

# %%
from sklearn.metrics import roc_auc_score

# %%
naive_proba = naive_model.predict_proba(x_test)

# %%
roc_auc_score(y_test, naive_proba, multi_class="ovo")
# Out:
# np.float64(0.9921810699588477)

# %%
knn_proba = knn_model.predict_proba(x_test)

# %%
roc_auc_score(y_test, knn_proba, multi_class="ovo")
# Out:
# np.float64(0.870432098765432)

# %%
decision_proba = decision_model.predict_proba(x_test)

# %%
roc_auc_score(y_test, decision_proba, multi_class="ovo")
# Out:
# np.float64(0.9951748971193416)
