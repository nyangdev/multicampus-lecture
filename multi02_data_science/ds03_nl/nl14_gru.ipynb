# %% [markdown]
# GRU (Gate Recurrent Unit)
#
# - LSTM 의 cell state 간소화 : update gate, reset gate
# - LSTM 보다 속도가 빠르다

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
x_train_pad = pad_sequences(x_train, maxlen=500)
x_test_pad = pad_sequences(x_train, maxlen=500)

# %%
model = Sequential()

# %%
# back propagation 오류역전파... 언젠간 여유 생기면 공부 해보시기

# %%
model.add(Embedding(10000, 10))

model.add(GRU(10, dropout=0.3, return_sequences=True))
model.add(GRU(10, dropout=0.3, return_sequences=True))
model.add(GRU(10))

model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["acc"])

# %%
result = model.fit(x_train_pad, y_train, batch_size=100, epochs=100, callbacks=[EarlyStopping(patience=3)], validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 66s 312ms/step - acc: 0.5866 - loss: 0.6579 - val_acc: 0.8066 - val_loss: 0.4388
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 62s 311ms/step - acc: 0.8286 - loss: 0.3956 - val_acc: 0.8188 - val_loss: 0.4118
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 67s 333ms/step - acc: 0.8678 - loss: 0.3198 - val_acc: 0.8480 - val_loss: 0.3675
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 75s 377ms/step - acc: 0.8938 - loss: 0.2692 - val_acc: 0.8380 - val_loss: 0.3953
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 321ms/step - acc: 0.9117 - loss: 0.2315 - val_acc: 0.8428 - val_loss: 0.3738
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 368ms/step - acc: 0.9260 - loss: 0.1995 - val_acc: 0.8460 - val_loss: 0.3798

# %%
model.evaluate(x_test_pad, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 124ms/step - acc: 0.4941 - loss: 1.7524
# [1.7215065956115723, 0.49724000692367554]
