# %%
import tensorflow.compat.v1 as tf

# %%
# 1. 데이터 준비
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)

# %%
# 2. 데이터 분할 (생략)

# %%
# 3. 모델 준비
# h = w * x + b
# random_normal : w와 b의 초기값을 표준분포에서 랜덤으로 정하겠다.
w = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

h = w * x + b

# %%
# loss function "mse"
loss = tf.reduce_mean(tf.square(h - y))

# %%
# optimizer "gd"
learning_rate = 0.01

optimizer = tf.train.GradientDescentOptimizer(learning_rate)

# %%
# 학습 방법 : loss를 최소화 하는 방향으로
train = optimizer.minimize(loss)

# %%
# 4. 환경 설정 (변수 초기화)
sess = tf.Session()

sess.run(tf.global_variables_initializer())

# %%
# 5. 학습
epochs = 1000
for step in range(epochs):
    _, loss_val, w_val, b_val = sess.run([train, loss, w, b], feed_dict={x:[1, 2, 3, 4], y:[3, 5, 7, 9]})
    if step % 100 == 0:
        print(f"w: {w_val} \t b: {b_val} \t loss: {loss_val}")
# Out:
# w: [0.92804205] 	 b: [0.86932087] 	 loss: 13.451162338256836
# w: [1.9471629] 	 b: [1.1553473] 	 loss: 0.004054723773151636
# w: [1.9608508] 	 b: [1.1151026] 	 loss: 0.0022259822580963373
# w: [1.970993] 	 b: [1.085284] 	 loss: 0.0012220462085679173
# w: [1.9785076] 	 b: [1.0631902] 	 loss: 0.00067089160438627
# w: [1.9840755] 	 b: [1.0468198] 	 loss: 0.00036830815952271223
# w: [1.9882009] 	 b: [1.034691] 	 loss: 0.00020220053556840867
# w: [1.9912574] 	 b: [1.0257044] 	 loss: 0.00011101150448666885
# w: [1.9935224] 	 b: [1.0190452] 	 loss: 6.094237323850393e-05
# w: [1.9952004] 	 b: [1.0141113] 	 loss: 3.345610821270384e-05

# %%
# 6. 평가 (버전 충돌)
loss_val = sess.run(loss, feed_dict={x:[5, 6, 7], y:[11, 13, 15]})
loss_val
# Out:
# 0.00012761401

# %%
# 7. 예측
sess.run(h, feed_dict={x:[10, 11, 12, 13]})
# Out:
# array([20.974817, 22.97125 , 24.967684, 26.964117], dtype=float32)
